# %% [markdown]
# ### Convert a PUBMD File to CSV

# %%
import pandas as pd

# %%
filename = "pubmed-virus-set_10000.txt"
SOURCE = f'../Src/{filename}'
DESTINATION = f"../Src_Parsed/{filename.split('.')[0]}.csv"

# %%
text_file = open(SOURCE,'r',encoding='utf8')

# %%
# Split Items
text_file.seek(0)
previous_key = None
rows = [{}]

for line in text_file.readlines():
    if(line.startswith("\n")):
        is_append = True
        rows.append({})
        continue
    
    if(line.startswith(" ")):
        rows[-1][previous_key] = rows[-1][previous_key] + line.strip().replace("\n","")
        continue
    
    previous_key,content = line.split("-",1)
    previous_key = previous_key.strip()
    rows[-1][previous_key] = content.strip()

# %%
pd.DataFrame(rows).to_csv(DESTINATION,index=False)

# %%
df = pd.read_csv(DESTINATION)
df.head()
# Out:
# G:\KLUEDU\Text Mining\Python Notebooks\env\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (58,59,60,61,62,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        PMID  OWN     STAT      DCOM        LR                   IS  VI   IP  \
# 0  30676241  NLM  MEDLINE  20200228  20201213  2164-5515 (Linking)  15  7-8
# 1  29217317  NLM  MEDLINE  20180504  20200409  0195-5616 (Linking)  48    2
# 2  28774498  NLM  MEDLINE  20180220  20181202  0149-2918 (Linking)  39    8
# 3  25483505  NLM  MEDLINE  20160515  20181202  2164-5515 (Linking)  10    9
# 4  27810314  NLM  MEDLINE  20171211  20181202  0264-410X (Linking)  34   52
#
#             DP                                                 TI  ...  FIR  \
# 0         2019  Addressing HPV vaccine myths: practical inform...  ...  NaN
# 1     2018 Mar           Recent Advances in Vaccine Technologies.  ...  NaN
# ...
